# %% [markdown]
# <a href="https://colab.research.google.com/github/git-arsalan/python_Lecture_Zafar_Iqbal/blob/main/03_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables: These are the containers to store data at certain memory location

# %%
id = 1234
name = 'MARTIN'
phone = '+44 33 222 12345'
email = 'email@gmail.com'

# %%
print(id)
print(name)
print(phone)
print(email)
# Out:
# 1234
# MARTIN
# +44 33 222 12345
# email@gmail.com

# %%
x=10
y=5
add = x+y
print(add)
# Out:
# 15
# 15

# %% [markdown]
# Variable Name cannot be start with number in python

# %%
8x =2
# Out:
#   File "/tmp/ipython-input-2778677890.py", line 1
#     8x =2
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# variable Name cannot be start with special chars except of _

# %%
*32 = 2
# Out:
#   File "/tmp/ipython-input-1233363131.py", line 1
#     *32 = 2
#      ^
# SyntaxError: cannot assign to literal

# %%
_x = 2
print (_x + -x)
# Out:
# -8

# %%
input("Enter your Name")
# Out:
# Enter your NameSHACK
# 'SHACK'

# %% [markdown]
# Assinging input result under variable

# %%
name = input ("Enter your Name")
print(name)
# Out:
# Enter your NameARSALAN
# ARSALAN

# %%
# string concatenation
name = input ("Enter your Name")
print("Hello " + name)
# Out:
# Enter your NameZAFAR
# Hello ZAFAR

# %%
# string is an array of characters. lets see the example
name = "MARTIN"
print(name[0])
print(name[1])
# Out:
# M
# A

# %%
# string array indexing can also be in negative. lets see the example
name = "MARTIN"
print(name[-1])
print(name[-2])
# Out:
# N
# I
