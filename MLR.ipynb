# %% [markdown]
# <a href="https://colab.research.google.com/github/git-arsalan/python_Lecture_Zafar_Iqbal/blob/ML_Module/MLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRACTICING MULTIPLE LINEAR REGRESSION
# ### FORMULA
# Y = B0 + B1X1 + B2X2 + ..... + B3X3

# %% [markdown]
# HERE WE HAVE A DATASET CONTAINNIG INDEPENDENT VARIABLE CONSISTS OF YEAR , CYLINDER AND MILEAGE OF WHICH IS USED TO PREDICT A DEPENDENT VARIABLE WHICH IS PRICE, SO THE FORMULA IS AS FOLLOWS:
# Price = m1*Year + m2*cylinder + m3*mileage + b

# %%
# now first we import desired libraries
import numpy as np
import pandas as pd
from sklearn import linear_model
