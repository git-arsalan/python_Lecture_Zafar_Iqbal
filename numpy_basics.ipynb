# %% [markdown]
# <a href="https://colab.research.google.com/github/git-arsalan/python_Lecture_Zafar_Iqbal/blob/main/numpy_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy

# %%
import numpy as np
np_array = np.array([[[1,2,3],[1,2,3],[4,5,6]],
                    [[1,2,3],[1,2,3],[4,5,6]],
                     [[1,2,3],[4,5,6],[4,5,6]]
                    ])
np_array
# Out:
# array([[[1, 2, 3],
#         [1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6],
#         [4, 5, 6]]])

# %%
print(f'dimension of np array is {np_array.ndim}')
print(f'shape of np array is {np_array.shape}')
# size of np array
print(f'size of np array is {np_array.size}')
# Out:
# dimension of np array is 3
# shape of np array is (3, 3, 3)
# size of np array is 27
