# %% [markdown]
# <a href="https://colab.research.google.com/github/git-arsalan/python_Lecture_Zafar_Iqbal/blob/main/Lecture_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("PAKISTAN ZINDABAD") # Displaying Text, Text should always be used within Double qoutes
# Out:
# PAKISTAN ZINDABAD

# %% [markdown]
# PRINT a number using PRINT Function

# %%
print(100) # Displaying Number, Number should be used without quotes
# Out:
# 100

# %%
print("YES! I CAN LEARN PYTHON...")
# Out:
# YES! I CAN LEARN PYTHON...
