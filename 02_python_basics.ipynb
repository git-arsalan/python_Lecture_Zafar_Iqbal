# %% [markdown]
# <a href="https://colab.research.google.com/github/git-arsalan/python_Lecture_Zafar_Iqbal/blob/main/02_python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # used to comment out lines in python. compiler donot consider these lines to execute
print("There is comment above in code")
# Out:
# There is comment above in code

# %% [markdown]
# **String can be defined in single quotes or double quotes**

# %%
"Hello python" # double quotes
#'Hello python' # single quotes
# Out:
# 'Hello python'
